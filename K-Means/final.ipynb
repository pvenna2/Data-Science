# %%
import os

# Setting Configurations - JAVA_HOME and SPARK_HOME Variable

os.environ["JAVA_HOME"] = r"C:\Program Files\Java\jdk1.8.0_251"
os.environ["SPARK_HOME"] = r"C:\Users\ASUS\Desktop\fiverracc2222\spark-3.2.1-bin-hadoop3.2"

# %% [markdown]
# ## Creating a Spark Context

# %%
# Import required modules

from pyspark.sql import functions
import pandas as pd

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# # 1.	Import the MovieLens dataset.

# %%
from pyspark.mllib.recommendation import ALS, MatrixFactorizationModel, Rating

# Load and parse the data
data = spark.sparkContext.textFile("u.data")
ratings = data.map(lambda l: l.split('\t')).map(lambda l: Rating(int(l[0]), int(l[1]), float(l[2])))

llist = ratings.collect()

for line in llist:
    print (line)
# Out:
# Rating(user=196, product=242, rating=3.0)
# Rating(user=186, product=302, rating=3.0)
# Rating(user=22, product=377, rating=1.0)
# Rating(user=244, product=51, rating=2.0)
# Rating(user=166, product=346, rating=1.0)
# Rating(user=298, product=474, rating=4.0)
# Rating(user=115, product=265, rating=2.0)
# Rating(user=253, product=465, rating=5.0)
# Rating(user=305, product=451, rating=3.0)
# Rating(user=6, product=86, rating=3.0)
# Rating(user=62, product=257, rating=2.0)
# Rating(user=286, product=1014, rating=5.0)
# Rating(user=200, product=222, rating=5.0)
# Rating(user=210, product=40, rating=3.0)
# Rating(user=224, product=29, rating=3.0)
# Rating(user=303, product=785, rating=3.0)
# Rating(user=122, product=387, rating=5.0)
# Rating(user=194, product=274, rating=2.0)
# Rating(user=291, product=1042, rating=4.0)
# Rating(user=234, product=1184, rating=2.0)
# Rating(user=119, product=392, rating=4.0)
# Rating(user=167, product=486, rating=4.0)
# Rating(user=299, product=144, rating=4.0)
# Rating(user=291, product=118, rating=2.0)
# Rating(user=308, product=1, rating=4.0)
# Rating(user=95, product=546, rating=2.0)
# Rating(user=38, product=95, rating=5.0)
# Rating(user=102, product=768, rating=2.0)
# Rating(user=63, product=277, rating=4.0)
# Rating(user=160, product=234, rating=5.0)
# Rating(user=50, product=246, rating=3.0)
# Rating(user=301, product=98, rating=4.0)
# Rating(user=225, product=193, rating=4.0)
# Rating(user=290, product=88, rating=4.0)
# Rating(user=97, product=194, rating=3.0)
# Rating(user=157, product=274, rating=4.0)
# Rating(user=181, product=1081, rating=1.0)
# Rating(user=278, product=603, rating=5.0)
# Rating(user=276, product=796, rating=1.0)
# Rating(user=7, product=32, rating=4.0)
# Rating(user=10, product=16, rating=4.0)
# Rating(user=284, product=304, rating=4.0)
# Rating(user=201, product=979, rating=2.0)
# Rating(user=276, product=564, rating=3.0)
# Rating(user=287, product=327, rating=5.0)
# Rating(user=246, product=201, rating=5.0)
# Rating(user=242, product=1137, rating=5.0)
# Rating(user=249, product=241, rating=5.0)
# Rating(user=99, product=4, rating=5.0)
# Rating(user=178, product=332, rating=3.0)
# Rating(user=251, product=100, rating=4.0)
# Rating(user=81, product=432, rating=2.0)
# Rating(user=260, product=322, rating=4.0)
# Rating(user=25, product=181, rating=5.0)
# Rating(user=59, product=196, rating=5.0)
# Rating(user=72, product=679, rating=2.0)
# Rating(user=87, product=384, rating=4.0)
# Rating(user=290, product=143, rating=5.0)
# Rating(user=42, product=423, rating=5.0)
# Rating(user=292, product=515, rating=4.0)
# Rating(user=115, product=20, rating=3.0)
# Rating(user=20, product=288, rating=1.0)
# Rating(user=201, product=219, rating=4.0)
# Rating(user=13, product=526, rating=3.0)
# Rating(user=246, product=919, rating=4.0)
# Rating(user=138, product=26, rating=5.0)
# Rating(user=167, product=232, rating=1.0)
# Rating(user=60, product=427, rating=5.0)
# Rating(user=57, product=304, rating=5.0)
# Rating(user=223, product=274, rating=4.0)
# Rating(user=189, product=512, rating=4.0)
# Rating(user=243, product=15, rating=3.0)
# Rating(user=92, product=1049, rating=1.0)
# Rating(user=246, product=416, rating=3.0)
# Rating(user=194, product=165, rating=4.0)
# Rating(user=241, product=690, rating=2.0)
# Rating(user=178, product=248, rating=4.0)
# Rating(user=254, product=1444, rating=3.0)
# Rating(user=293, product=5, rating=3.0)
# Rating(user=127, product=229, rating=5.0)
# Rating(user=225, product=237, rating=5.0)
# Rating(user=299, product=229, rating=3.0)
# Rating(user=225, product=480, rating=5.0)
# Rating(user=276, product=54, rating=3.0)
# Rating(user=291, product=144, rating=5.0)
# Rating(user=222, product=366, rating=4.0)
# Rating(user=267, product=518, rating=5.0)
# Rating(user=42, product=403, rating=3.0)
# Rating(user=11, product=111, rating=4.0)
# Rating(user=95, product=625, rating=4.0)
# Rating(user=8, product=338, rating=4.0)
# Rating(user=162, product=25, rating=4.0)
# Rating(user=87, product=1016, rating=4.0)
# Rating(user=279, product=154, rating=5.0)
# Rating(user=145, product=275, rating=2.0)
# Rating(user=119, product=1153, rating=5.0)
# Rating(user=62, product=498, rating=4.0)
# Rating(user=62, product=382, rating=3.0)
# Rating(user=28, product=209, rating=4.0)
# Rating(user=135, product=23, rating=4.0)
# Rating(user=32, product=294, rating=3.0)
# Rating(user=90, product=382, rating=5.0)
# Rating(user=286, product=208, rating=4.0)
# Rating(user=293, product=685, rating=3.0)
# Rating(user=216, product=144, rating=4.0)
# Rating(user=166, product=328, rating=5.0)
# Rating(user=250, product=496, rating=4.0)
# Rating(user=271, product=132, rating=5.0)
# Rating(user=160, product=174, rating=5.0)
# Rating(user=265, product=118, rating=4.0)
# Rating(user=198, product=498, rating=3.0)
# Rating(user=42, product=96, rating=5.0)
# Rating(user=168, product=151, rating=5.0)
# Rating(user=110, product=307, rating=4.0)
# Rating(user=58, product=144, rating=4.0)
# Rating(user=90, product=648, rating=4.0)
# Rating(user=271, product=346, rating=4.0)
# Rating(user=62, product=21, rating=3.0)
# Rating(user=279, product=832, rating=3.0)
# Rating(user=237, product=514, rating=4.0)
# Rating(user=94, product=789, rating=4.0)
# Rating(user=128, product=485, rating=3.0)
# Rating(user=298, product=317, rating=4.0)
# Rating(user=44, product=195, rating=5.0)
# Rating(user=264, product=200, rating=5.0)
# Rating(user=194, product=385, rating=2.0)
# Rating(user=72, product=195, rating=5.0)
# Rating(user=222, product=750, rating=5.0)
# Rating(user=250, product=264, rating=3.0)
# Rating(user=41, product=265, rating=3.0)
# Rating(user=224, product=245, rating=3.0)
# Rating(user=82, product=135, rating=3.0)
# Rating(user=262, product=1147, rating=4.0)
# Rating(user=293, product=471, rating=3.0)
# Rating(user=216, product=658, rating=3.0)
# Rating(user=250, product=140, rating=3.0)
# Rating(user=59, product=23, rating=5.0)
# Rating(user=286, product=379, rating=5.0)
# Rating(user=244, product=815, rating=4.0)
# Rating(user=7, product=479, rating=4.0)
# Rating(user=174, product=368, rating=1.0)
# Rating(user=87, product=274, rating=4.0)
# Rating(user=194, product=1211, rating=2.0)
# Rating(user=82, product=1134, rating=2.0)
# Rating(user=13, product=836, rating=2.0)
# Rating(user=13, product=272, rating=4.0)
# Rating(user=244, product=756, rating=2.0)
# Rating(user=305, product=427, rating=5.0)
# Rating(user=95, product=787, rating=2.0)
# Rating(user=43, product=14, rating=2.0)
# Rating(user=299, product=955, rating=4.0)
# Rating(user=57, product=419, rating=3.0)
# Rating(user=84, product=405, rating=3.0)
# Rating(user=269, product=504, rating=4.0)
# Rating(user=299, product=111, rating=3.0)
# Rating(user=194, product=466, rating=4.0)
# Rating(user=160, product=135, rating=4.0)
# Rating(user=99, product=268, rating=3.0)
# Rating(user=10, product=486, rating=4.0)
# Rating(user=259, product=117, rating=4.0)
# Rating(user=85, product=427, rating=3.0)
# Rating(user=303, product=919, rating=4.0)
# Rating(user=213, product=273, rating=5.0)
# Rating(user=121, product=514, rating=3.0)
# Rating(user=90, product=98, rating=5.0)
# Rating(user=49, product=559, rating=2.0)
# Rating(user=42, product=794, rating=3.0)
# Rating(user=155, product=323, rating=2.0)
# Rating(user=68, product=117, rating=4.0)
# Rating(user=172, product=177, rating=4.0)
# Rating(user=19, product=4, rating=4.0)
# Rating(user=268, product=231, rating=4.0)
# Rating(user=5, product=2, rating=3.0)
# Rating(user=305, product=117, rating=2.0)
# Rating(user=44, product=294, rating=4.0)
# Rating(user=43, product=137, rating=4.0)
# Rating(user=279, product=1336, rating=1.0)
# Rating(user=80, product=466, rating=5.0)
# Rating(user=254, product=164, rating=4.0)
# Rating(user=298, product=281, rating=3.0)
# Rating(user=279, product=1240, rating=1.0)
# Rating(user=66, product=298, rating=4.0)
# Rating(user=18, product=443, rating=3.0)
# Rating(user=268, product=1035, rating=2.0)
# Rating(user=99, product=79, rating=4.0)
# Rating(user=13, product=98, rating=4.0)
# Rating(user=26, product=258, rating=3.0)
# Rating(user=7, product=455, rating=4.0)
# Rating(user=222, product=755, rating=4.0)
# Rating(user=200, product=673, rating=5.0)
# Rating(user=119, product=328, rating=4.0)
# Rating(user=213, product=172, rating=5.0)
# Rating(user=276, product=322, rating=3.0)
# Rating(user=94, product=1217, rating=3.0)
# Rating(user=130, product=379, rating=4.0)
# Rating(user=38, product=328, rating=4.0)
# Rating(user=160, product=719, rating=3.0)
# Rating(user=293, product=1267, rating=3.0)
# Rating(user=26, product=930, rating=2.0)
# Rating(user=130, product=216, rating=4.0)
# Rating(user=92, product=1079, rating=3.0)
# Rating(user=256, product=452, rating=4.0)
# Rating(user=1, product=61, rating=4.0)
# Rating(user=72, product=48, rating=4.0)
# Rating(user=56, product=755, rating=3.0)
# Rating(user=13, product=360, rating=4.0)
# Rating(user=15, product=405, rating=2.0)
# Rating(user=92, product=77, rating=3.0)
# Rating(user=207, product=476, rating=2.0)
# Rating(user=292, product=174, rating=5.0)
# Rating(user=232, product=483, rating=5.0)
# Rating(user=251, product=748, rating=2.0)
# Rating(user=224, product=26, rating=3.0)
# Rating(user=181, product=220, rating=4.0)
# Rating(user=259, product=255, rating=4.0)
# Rating(user=305, product=471, rating=4.0)
# Rating(user=52, product=280, rating=3.0)
# Rating(user=161, product=202, rating=5.0)
# Rating(user=148, product=408, rating=5.0)
# Rating(user=125, product=235, rating=2.0)
# Rating(user=97, product=228, rating=5.0)
# Rating(user=58, product=1098, rating=4.0)
# Rating(user=83, product=234, rating=4.0)
# Rating(user=90, product=347, rating=4.0)
# Rating(user=272, product=178, rating=5.0)
# Rating(user=194, product=181, rating=3.0)
# Rating(user=125, product=478, rating=4.0)
# Rating(user=110, product=688, rating=1.0)
# Rating(user=299, product=14, rating=4.0)
# Rating(user=151, product=10, rating=5.0)
# Rating(user=269, product=127, rating=4.0)
# Rating(user=6, product=14, rating=5.0)
# Rating(user=54, product=106, rating=3.0)
# Rating(user=303, product=69, rating=5.0)
# Rating(user=16, product=944, rating=1.0)
# Rating(user=301, product=790, rating=4.0)
# Rating(user=276, product=1091, rating=3.0)
# Rating(user=305, product=214, rating=2.0)
# Rating(user=194, product=1028, rating=2.0)
# Rating(user=91, product=323, rating=2.0)
# Rating(user=87, product=554, rating=4.0)
# Rating(user=294, product=109, rating=4.0)
# Rating(user=286, product=171, rating=4.0)
# Rating(user=200, product=318, rating=5.0)
# Rating(user=229, product=328, rating=1.0)
# Rating(user=178, product=568, rating=4.0)
# Rating(user=303, product=842, rating=2.0)
# Rating(user=62, product=65, rating=4.0)
# Rating(user=207, product=591, rating=3.0)
# Rating(user=92, product=172, rating=4.0)
# Rating(user=301, product=401, rating=4.0)
# Rating(user=36, product=339, rating=5.0)
# Rating(user=70, product=746, rating=3.0)
# Rating(user=63, product=242, rating=3.0)
# Rating(user=28, product=201, rating=3.0)
# Rating(user=279, product=68, rating=4.0)
# Rating(user=250, product=7, rating=4.0)
# Rating(user=14, product=98, rating=3.0)
# Rating(user=299, product=1018, rating=3.0)
# Rating(user=194, product=54, rating=3.0)
# Rating(user=303, product=815, rating=3.0)
# Rating(user=119, product=237, rating=5.0)
# Rating(user=295, product=218, rating=5.0)
# Rating(user=268, product=930, rating=2.0)
# Rating(user=268, product=2, rating=2.0)
# Rating(user=66, product=258, rating=4.0)
# Rating(user=233, product=202, rating=5.0)
# Rating(user=83, product=623, rating=4.0)
# Rating(user=214, product=334, rating=3.0)
# Rating(user=192, product=476, rating=2.0)
# Rating(user=100, product=344, rating=4.0)
# Rating(user=268, product=145, rating=1.0)
# Rating(user=301, product=56, rating=4.0)
# Rating(user=307, product=89, rating=5.0)
# Rating(user=234, product=141, rating=3.0)
# Rating(user=83, product=576, rating=4.0)
# Rating(user=181, product=264, rating=2.0)
# Rating(user=297, product=133, rating=4.0)
# Rating(user=38, product=153, rating=5.0)
# Rating(user=7, product=382, rating=4.0)
# Rating(user=264, product=813, rating=4.0)
# Rating(user=181, product=872, rating=1.0)
# Rating(user=201, product=146, rating=1.0)
# Rating(user=85, product=507, rating=4.0)
# Rating(user=269, product=367, rating=3.0)
# Rating(user=59, product=468, rating=3.0)
# Rating(user=286, product=143, rating=4.0)
# Rating(user=193, product=96, rating=1.0)
# Rating(user=113, product=595, rating=5.0)
# Rating(user=292, product=11, rating=5.0)
# Rating(user=130, product=1014, rating=3.0)
# Rating(user=275, product=98, rating=4.0)
# Rating(user=189, product=520, rating=5.0)
# Rating(user=219, product=82, rating=1.0)
# Rating(user=218, product=209, rating=5.0)
# Rating(user=123, product=427, rating=3.0)
# Rating(user=119, product=222, rating=5.0)
# Rating(user=158, product=177, rating=4.0)
# Rating(user=222, product=118, rating=4.0)
# Rating(user=302, product=322, rating=2.0)
# Rating(user=279, product=501, rating=3.0)
# Rating(user=301, product=79, rating=5.0)
# Rating(user=181, product=3, rating=2.0)
# Rating(user=201, product=695, rating=1.0)
# Rating(user=13, product=198, rating=3.0)
# Rating(user=1, product=189, rating=3.0)
# Rating(user=145, product=237, rating=5.0)
# Rating(user=23, product=385, rating=4.0)
# Rating(user=201, product=767, rating=4.0)
# Rating(user=296, product=705, rating=5.0)
# Rating(user=42, product=546, rating=3.0)
# Rating(user=33, product=872, rating=3.0)
# Rating(user=301, product=554, rating=3.0)
# Rating(user=16, product=64, rating=5.0)
# Rating(user=95, product=135, rating=3.0)
# Rating(user=154, product=357, rating=4.0)
# Rating(user=77, product=484, rating=5.0)
# Rating(user=296, product=508, rating=5.0)
# Rating(user=302, product=303, rating=2.0)
# Rating(user=244, product=673, rating=3.0)
# Rating(user=222, product=77, rating=4.0)
# Rating(user=13, product=215, rating=5.0)
# Rating(user=16, product=705, rating=5.0)
# Rating(user=270, product=452, rating=4.0)
# Rating(user=145, product=15, rating=2.0)
# Rating(user=187, product=64, rating=5.0)
# Rating(user=200, product=304, rating=5.0)
# Rating(user=170, product=749, rating=5.0)
# Rating(user=101, product=829, rating=3.0)
# Rating(user=184, product=218, rating=3.0)
# Rating(user=128, product=204, rating=4.0)
# Rating(user=181, product=1295, rating=1.0)
# Rating(user=184, product=153, rating=3.0)
# Rating(user=1, product=33, rating=4.0)
# Rating(user=1, product=160, rating=4.0)
# Rating(user=184, product=321, rating=5.0)
# Rating(user=54, product=595, rating=3.0)
# Rating(user=94, product=343, rating=4.0)
# Rating(user=128, product=508, rating=4.0)
# Rating(user=23, product=323, rating=2.0)
# Rating(user=301, product=227, rating=3.0)
# Rating(user=301, product=191, rating=3.0)
# Rating(user=112, product=903, rating=1.0)
# Rating(user=82, product=183, rating=3.0)
# Rating(user=222, product=724, rating=3.0)
# Rating(user=218, product=430, rating=3.0)
# Rating(user=308, product=1197, rating=4.0)
# Rating(user=303, product=134, rating=5.0)
# Rating(user=133, product=751, rating=3.0)
# Rating(user=215, product=212, rating=2.0)
# Rating(user=69, product=256, rating=5.0)
# Rating(user=254, product=662, rating=4.0)
# Rating(user=276, product=2, rating=4.0)
# Rating(user=104, product=984, rating=1.0)
# Rating(user=63, product=1067, rating=3.0)
# Rating(user=267, product=410, rating=4.0)
# Rating(user=13, product=56, rating=5.0)
# Rating(user=240, product=879, rating=3.0)
# Rating(user=286, product=237, rating=2.0)
# Rating(user=294, product=271, rating=5.0)
# Rating(user=90, product=1086, rating=4.0)
# Rating(user=18, product=26, rating=4.0)
# Rating(user=92, product=229, rating=3.0)
# Rating(user=308, product=649, rating=4.0)
# Rating(user=144, product=89, rating=3.0)
# Rating(user=191, product=302, rating=4.0)
# Rating(user=59, product=951, rating=3.0)
# Rating(user=200, product=96, rating=5.0)
# Rating(user=16, product=197, rating=5.0)
# Rating(user=61, product=678, rating=3.0)
# Rating(user=271, product=199, rating=4.0)
# Rating(user=271, product=709, rating=3.0)
# Rating(user=142, product=169, rating=5.0)
# Rating(user=275, product=597, rating=3.0)
# Rating(user=222, product=151, rating=3.0)
# Rating(user=87, product=40, rating=3.0)
# Rating(user=207, product=258, rating=4.0)
# Rating(user=272, product=1393, rating=2.0)
# Rating(user=177, product=333, rating=4.0)
# Rating(user=207, product=1115, rating=2.0)
# Rating(user=299, product=577, rating=3.0)
# Rating(user=271, product=378, rating=4.0)
# Rating(user=305, product=425, rating=4.0)
# Rating(user=49, product=959, rating=2.0)
# Rating(user=94, product=1224, rating=3.0)
# Rating(user=130, product=1017, rating=3.0)
# Rating(user=10, product=175, rating=3.0)
# Rating(user=203, product=321, rating=3.0)
# Rating(user=191, product=286, rating=4.0)
# Rating(user=43, product=323, rating=3.0)
# Rating(user=21, product=558, rating=5.0)
# Rating(user=197, product=96, rating=5.0)
# Rating(user=13, product=344, rating=2.0)
# Rating(user=194, product=66, rating=3.0)
# Rating(user=234, product=206, rating=4.0)
# Rating(user=308, product=402, rating=4.0)
# Rating(user=308, product=640, rating=4.0)
# Rating(user=269, product=522, rating=5.0)
# Rating(user=94, product=265, rating=4.0)
# Rating(user=268, product=62, rating=3.0)
# Rating(user=272, product=12, rating=5.0)
# Rating(user=121, product=291, rating=3.0)
# Rating(user=296, product=20, rating=5.0)
# Rating(user=134, product=286, rating=3.0)
# Rating(user=180, product=462, rating=5.0)
# Rating(user=234, product=612, rating=3.0)
# Rating(user=104, product=117, rating=2.0)
# Rating(user=38, product=758, rating=1.0)
# Rating(user=269, product=845, rating=1.0)
# Rating(user=7, product=163, rating=4.0)
# Rating(user=234, product=1451, rating=3.0)
# Rating(user=275, product=405, rating=2.0)
# Rating(user=52, product=250, rating=3.0)
# Rating(user=102, product=823, rating=3.0)
# Rating(user=13, product=186, rating=4.0)
# Rating(user=178, product=731, rating=4.0)
# Rating(user=236, product=71, rating=3.0)
# Rating(user=256, product=781, rating=5.0)
# Rating(user=263, product=176, rating=5.0)
# Rating(user=244, product=186, rating=3.0)
# Rating(user=279, product=1181, rating=4.0)
# Rating(user=43, product=815, rating=4.0)
# Rating(user=83, product=78, rating=2.0)
# Rating(user=151, product=197, rating=5.0)
# Rating(user=254, product=436, rating=2.0)
# Rating(user=109, product=631, rating=3.0)
# Rating(user=297, product=716, rating=3.0)
# Rating(user=249, product=188, rating=4.0)
# Rating(user=144, product=699, rating=4.0)
# Rating(user=301, product=604, rating=4.0)
# Rating(user=64, product=392, rating=3.0)
# Rating(user=92, product=501, rating=2.0)
# Rating(user=222, product=97, rating=4.0)
# Rating(user=268, product=436, rating=3.0)
# Rating(user=293, product=135, rating=5.0)
# Rating(user=213, product=173, rating=5.0)
# Rating(user=160, product=460, rating=2.0)
# Rating(user=13, product=498, rating=4.0)
# Rating(user=59, product=715, rating=5.0)
# Rating(user=5, product=17, rating=4.0)
# Rating(user=125, product=163, rating=5.0)
# Rating(user=174, product=315, rating=5.0)
# Rating(user=114, product=505, rating=3.0)
# Rating(user=213, product=515, rating=4.0)
# Rating(user=23, product=196, rating=2.0)
# Rating(user=128, product=15, rating=4.0)
# Rating(user=239, product=56, rating=4.0)
# Rating(user=181, product=279, rating=1.0)
# Rating(user=291, product=80, rating=4.0)
# Rating(user=250, product=238, rating=4.0)
# Rating(user=201, product=649, rating=3.0)
# Rating(user=60, product=60, rating=5.0)
# Rating(user=181, product=325, rating=2.0)
# Rating(user=119, product=407, rating=3.0)
# Rating(user=287, product=1, rating=5.0)
# Rating(user=216, product=228, rating=3.0)
# Rating(user=216, product=531, rating=4.0)
# Rating(user=203, product=471, rating=4.0)
# Rating(user=92, product=587, rating=3.0)
# Rating(user=13, product=892, rating=3.0)
# Rating(user=213, product=176, rating=4.0)
# Rating(user=286, product=288, rating=5.0)
# Rating(user=117, product=1047, rating=2.0)
# Rating(user=99, product=111, rating=1.0)
# Rating(user=11, product=558, rating=3.0)
# Rating(user=65, product=47, rating=2.0)
# Rating(user=295, product=194, rating=4.0)
# Rating(user=269, product=217, rating=2.0)
# Rating(user=85, product=259, rating=2.0)
# Rating(user=250, product=596, rating=5.0)
# Rating(user=137, product=144, rating=5.0)
# Rating(user=201, product=960, rating=2.0)
# Rating(user=257, product=137, rating=4.0)
# Rating(user=111, product=328, rating=4.0)
# Rating(user=91, product=480, rating=4.0)
# Rating(user=215, product=211, rating=4.0)
# Rating(user=181, product=938, rating=1.0)
# Rating(user=189, product=1060, rating=5.0)
# Rating(user=1, product=20, rating=4.0)
# Rating(user=303, product=404, rating=4.0)
# Rating(user=299, product=305, rating=3.0)
# Rating(user=187, product=210, rating=4.0)
# Rating(user=222, product=278, rating=2.0)
# Rating(user=214, product=568, rating=4.0)
# Rating(user=293, product=770, rating=3.0)
# Rating(user=285, product=191, rating=4.0)
# Rating(user=303, product=252, rating=3.0)
# Rating(user=96, product=156, rating=4.0)
# Rating(user=72, product=1110, rating=3.0)
# Rating(user=115, product=1067, rating=4.0)
# Rating(user=7, product=430, rating=3.0)
# Rating(user=116, product=350, rating=3.0)
# Rating(user=73, product=480, rating=4.0)
# Rating(user=269, product=246, rating=5.0)
# Rating(user=263, product=419, rating=5.0)
# Rating(user=70, product=431, rating=3.0)
# Rating(user=221, product=475, rating=4.0)
# Rating(user=72, product=182, rating=5.0)
# Rating(user=25, product=357, rating=4.0)
# Rating(user=290, product=50, rating=5.0)
# Rating(user=189, product=526, rating=4.0)
# Rating(user=299, product=303, rating=3.0)
# Rating(user=264, product=294, rating=3.0)
# Rating(user=200, product=365, rating=5.0)
# Rating(user=187, product=135, rating=4.0)
# Rating(user=184, product=187, rating=4.0)
# Rating(user=63, product=289, rating=2.0)
# Rating(user=13, product=229, rating=4.0)
# Rating(user=298, product=486, rating=3.0)
# Rating(user=235, product=185, rating=4.0)
# Rating(user=62, product=712, rating=4.0)
# Rating(user=246, product=94, rating=2.0)
# Rating(user=54, product=742, rating=5.0)
# Rating(user=63, product=762, rating=3.0)
# Rating(user=11, product=732, rating=3.0)
# Rating(user=92, product=168, rating=4.0)
# Rating(user=8, product=550, rating=3.0)
# Rating(user=307, product=174, rating=4.0)
# Rating(user=303, product=200, rating=4.0)
# Rating(user=256, product=849, rating=2.0)
# Rating(user=72, product=54, rating=3.0)
# Rating(user=164, product=406, rating=2.0)
# Rating(user=117, product=150, rating=4.0)
# Rating(user=224, product=77, rating=4.0)
# Rating(user=193, product=869, rating=3.0)
# Rating(user=94, product=184, rating=2.0)
# Rating(user=281, product=338, rating=2.0)
# Rating(user=130, product=109, rating=3.0)
# Rating(user=128, product=371, rating=1.0)
# Rating(user=94, product=720, rating=1.0)
# Rating(user=182, product=845, rating=3.0)
# Rating(user=129, product=873, rating=1.0)
# Rating(user=254, product=229, rating=4.0)
# Rating(user=64, product=381, rating=4.0)
# Rating(user=151, product=176, rating=2.0)
# Rating(user=45, product=25, rating=4.0)
# Rating(user=193, product=879, rating=3.0)
# Rating(user=276, product=922, rating=4.0)
# Rating(user=276, product=57, rating=3.0)
# Rating(user=234, product=187, rating=4.0)
# Rating(user=181, product=306, rating=1.0)
# Rating(user=21, product=370, rating=1.0)
# Rating(user=293, product=249, rating=3.0)
# Rating(user=264, product=721, rating=5.0)
# Rating(user=10, product=611, rating=5.0)
# Rating(user=197, product=346, rating=3.0)
# Rating(user=276, product=142, rating=3.0)
# Rating(user=308, product=427, rating=4.0)
# Rating(user=221, product=943, rating=4.0)
# Rating(user=131, product=126, rating=4.0)
# Rating(user=268, product=824, rating=2.0)
# Rating(user=109, product=8, rating=3.0)
# Rating(user=198, product=58, rating=3.0)
# Rating(user=230, product=680, rating=4.0)
# Rating(user=181, product=741, rating=1.0)
# Rating(user=192, product=1061, rating=4.0)
# Rating(user=234, product=448, rating=3.0)
# Rating(user=90, product=900, rating=4.0)
# Rating(user=193, product=941, rating=4.0)
# Rating(user=128, product=603, rating=5.0)
# Rating(user=126, product=905, rating=2.0)
# Rating(user=244, product=265, rating=4.0)
# Rating(user=90, product=289, rating=3.0)
# Rating(user=157, product=25, rating=3.0)
# Rating(user=305, product=71, rating=3.0)
# Rating(user=119, product=382, rating=5.0)
# Rating(user=21, product=222, rating=2.0)
# Rating(user=231, product=181, rating=4.0)
# Rating(user=280, product=508, rating=3.0)
# Rating(user=288, product=132, rating=3.0)
# Rating(user=279, product=1497, rating=2.0)
# Rating(user=301, product=33, rating=4.0)
# Rating(user=72, product=699, rating=3.0)
# Rating(user=90, product=259, rating=2.0)
# Rating(user=308, product=55, rating=3.0)
# Rating(user=59, product=742, rating=3.0)
# Rating(user=94, product=744, rating=4.0)
# Rating(user=130, product=642, rating=4.0)
# Rating(user=26, product=1015, rating=3.0)
# Rating(user=56, product=121, rating=5.0)
# Rating(user=82, product=508, rating=2.0)
# Rating(user=62, product=12, rating=4.0)
# Rating(user=276, product=40, rating=3.0)
# Rating(user=181, product=1015, rating=1.0)
# Rating(user=152, product=301, rating=3.0)
# Rating(user=178, product=845, rating=4.0)
# Rating(user=217, product=597, rating=4.0)
# Rating(user=79, product=303, rating=4.0)
# Rating(user=138, product=484, rating=4.0)
# Rating(user=308, product=81, rating=5.0)
# Rating(user=75, product=284, rating=2.0)
# Rating(user=269, product=198, rating=4.0)
# Rating(user=307, product=94, rating=3.0)
# Rating(user=222, product=781, rating=3.0)
# Rating(user=121, product=740, rating=3.0)
# Rating(user=269, product=22, rating=1.0)
# Rating(user=13, product=864, rating=4.0)
# Rating(user=230, product=742, rating=5.0)
# Rating(user=269, product=507, rating=4.0)
# Rating(user=239, product=1099, rating=5.0)
# Rating(user=245, product=1028, rating=5.0)
# Rating(user=56, product=546, rating=3.0)
# Rating(user=295, product=961, rating=5.0)
# Rating(user=271, product=1028, rating=2.0)
# Rating(user=222, product=812, rating=2.0)
# Rating(user=69, product=240, rating=3.0)
# Rating(user=10, product=7, rating=4.0)
# Rating(user=22, product=376, rating=3.0)
# Rating(user=294, product=931, rating=3.0)
# Rating(user=82, product=717, rating=1.0)
# Rating(user=279, product=399, rating=4.0)
# Rating(user=269, product=234, rating=1.0)
# Rating(user=6, product=98, rating=5.0)
# Rating(user=243, product=1039, rating=4.0)
# Rating(user=298, product=181, rating=4.0)
# Rating(user=282, product=325, rating=1.0)
# Rating(user=78, product=323, rating=1.0)
# Rating(user=118, product=200, rating=5.0)
# Rating(user=283, product=1114, rating=5.0)
# Rating(user=171, product=292, rating=4.0)
# Rating(user=70, product=217, rating=4.0)
# Rating(user=10, product=100, rating=5.0)
# Rating(user=245, product=181, rating=4.0)
# Rating(user=107, product=333, rating=3.0)
# Rating(user=246, product=561, rating=1.0)
# Rating(user=13, product=901, rating=1.0)
# Rating(user=276, product=70, rating=4.0)
# Rating(user=244, product=17, rating=2.0)
# Rating(user=189, product=56, rating=5.0)
# Rating(user=226, product=242, rating=5.0)
# Rating(user=62, product=1016, rating=4.0)
# Rating(user=276, product=417, rating=4.0)
# Rating(user=214, product=478, rating=4.0)
# Rating(user=306, product=235, rating=4.0)
# Rating(user=222, product=26, rating=3.0)
# Rating(user=280, product=631, rating=5.0)
# Rating(user=60, product=430, rating=5.0)
# Rating(user=56, product=71, rating=4.0)
# Rating(user=42, product=274, rating=5.0)
# Rating(user=1, product=202, rating=5.0)
# Rating(user=13, product=809, rating=4.0)
# Rating(user=173, product=289, rating=4.0)
# Rating(user=15, product=749, rating=1.0)
# Rating(user=185, product=23, rating=4.0)
# Rating(user=280, product=540, rating=3.0)
# Rating(user=244, product=381, rating=4.0)
# Rating(user=150, product=293, rating=4.0)
# Rating(user=7, product=497, rating=4.0)
# Rating(user=178, product=317, rating=4.0)
# Rating(user=178, product=742, rating=3.0)
# Rating(user=95, product=1217, rating=3.0)
# Rating(user=234, product=1462, rating=3.0)
# Rating(user=97, product=222, rating=5.0)
# Rating(user=109, product=127, rating=2.0)
# Rating(user=117, product=268, rating=5.0)
# Rating(user=269, product=705, rating=2.0)
# Rating(user=130, product=1246, rating=3.0)
# Rating(user=264, product=655, rating=4.0)
# Rating(user=207, product=13, rating=3.0)
# Rating(user=42, product=588, rating=5.0)
# Rating(user=246, product=409, rating=2.0)
# Rating(user=87, product=367, rating=4.0)
# Rating(user=101, product=304, rating=3.0)
# Rating(user=256, product=127, rating=4.0)
# Rating(user=92, product=794, rating=3.0)
# Rating(user=181, product=762, rating=2.0)
# Rating(user=213, product=235, rating=1.0)
# Rating(user=92, product=739, rating=2.0)
# Rating(user=292, product=661, rating=5.0)
# Rating(user=246, product=665, rating=4.0)
# Rating(user=274, product=845, rating=5.0)
# Rating(user=188, product=692, rating=5.0)
# Rating(user=18, product=86, rating=4.0)
# Rating(user=5, product=439, rating=1.0)
# Rating(user=236, product=632, rating=3.0)
# Rating(user=193, product=407, rating=4.0)
# Rating(user=144, product=709, rating=4.0)
# Rating(user=90, product=1198, rating=5.0)
# Rating(user=48, product=609, rating=4.0)
# Rating(user=5, product=225, rating=2.0)
# Rating(user=22, product=128, rating=5.0)
# Rating(user=311, product=432, rating=4.0)
# Rating(user=8, product=22, rating=5.0)
# Rating(user=276, product=188, rating=4.0)
# Rating(user=222, product=173, rating=5.0)
# Rating(user=72, product=866, rating=4.0)
# Rating(user=299, product=134, rating=4.0)
# Rating(user=1, product=171, rating=5.0)
# Rating(user=308, product=295, rating=3.0)
# Rating(user=165, product=216, rating=4.0)
# Rating(user=222, product=49, rating=3.0)
# Rating(user=181, product=121, rating=4.0)
# Rating(user=200, product=11, rating=5.0)
# Rating(user=234, product=626, rating=4.0)
# Rating(user=244, product=707, rating=4.0)
# Rating(user=90, product=25, rating=5.0)
# Rating(user=208, product=216, rating=5.0)
# Rating(user=263, product=96, rating=4.0)
# Rating(user=134, product=323, rating=4.0)
# Rating(user=279, product=586, rating=4.0)
# Rating(user=2, product=292, rating=4.0)
# Rating(user=288, product=593, rating=2.0)
# Rating(user=49, product=302, rating=4.0)
# Rating(user=286, product=153, rating=5.0)
# Rating(user=205, product=304, rating=3.0)
# Rating(user=22, product=80, rating=4.0)
# Rating(user=234, product=318, rating=4.0)
# Rating(user=223, product=328, rating=3.0)
# Rating(user=15, product=25, rating=3.0)
# Rating(user=268, product=147, rating=4.0)
# Rating(user=94, product=1220, rating=3.0)
# Rating(user=274, product=405, rating=4.0)
# Rating(user=7, product=492, rating=5.0)
# Rating(user=268, product=217, rating=2.0)
# Rating(user=16, product=55, rating=5.0)
# Rating(user=164, product=620, rating=3.0)
# Rating(user=290, product=161, rating=4.0)
# Rating(user=92, product=515, rating=4.0)
# Rating(user=239, product=1070, rating=5.0)
# Rating(user=56, product=449, rating=5.0)
# Rating(user=248, product=234, rating=4.0)
# Rating(user=234, product=10, rating=3.0)
# Rating(user=280, product=1049, rating=2.0)
# Rating(user=308, product=187, rating=5.0)
# Rating(user=276, product=64, rating=5.0)
# Rating(user=192, product=948, rating=3.0)
# Rating(user=122, product=509, rating=4.0)
# Rating(user=85, product=588, rating=3.0)
# Rating(user=262, product=931, rating=2.0)
# Rating(user=201, product=272, rating=3.0)
# Rating(user=181, product=870, rating=2.0)
# Rating(user=295, product=739, rating=4.0)
# Rating(user=263, product=568, rating=4.0)
# Rating(user=295, product=39, rating=4.0)
# Rating(user=201, product=1100, rating=4.0)
# Rating(user=93, product=820, rating=3.0)
# Rating(user=159, product=1028, rating=5.0)
# Rating(user=158, product=665, rating=2.0)
# Rating(user=293, product=423, rating=3.0)
# Rating(user=82, product=597, rating=3.0)
# Rating(user=276, product=181, rating=5.0)
# Rating(user=13, product=823, rating=5.0)
# Rating(user=217, product=2, rating=3.0)
# Rating(user=83, product=660, rating=4.0)
# Rating(user=189, product=20, rating=5.0)
# Rating(user=222, product=796, rating=4.0)
# Rating(user=146, product=1022, rating=5.0)
# Rating(user=267, product=121, rating=3.0)
# Rating(user=126, product=294, rating=3.0)
# Rating(user=181, product=1060, rating=1.0)
# Rating(user=125, product=80, rating=4.0)
# Rating(user=43, product=120, rating=4.0)
# Rating(user=13, product=780, rating=1.0)
# Rating(user=253, product=259, rating=2.0)
# Rating(user=42, product=44, rating=3.0)
# Rating(user=77, product=518, rating=4.0)
# Rating(user=291, product=686, rating=5.0)
# Rating(user=268, product=21, rating=3.0)
# Rating(user=262, product=28, rating=3.0)
# Rating(user=234, product=81, rating=3.0)
# Rating(user=29, product=245, rating=3.0)
# Rating(user=236, product=57, rating=5.0)
# Rating(user=158, product=729, rating=3.0)
# Rating(user=156, product=661, rating=4.0)
# Rating(user=232, product=52, rating=5.0)
# Rating(user=168, product=866, rating=5.0)
# Rating(user=37, product=288, rating=4.0)
# Rating(user=141, product=245, rating=3.0)
# Rating(user=235, product=230, rating=4.0)
# Rating(user=102, product=70, rating=3.0)
# Rating(user=77, product=172, rating=3.0)
# Rating(user=90, product=506, rating=5.0)
# Rating(user=186, product=566, rating=5.0)
# Rating(user=44, product=660, rating=5.0)
# Rating(user=118, product=774, rating=5.0)
# Rating(user=7, product=661, rating=5.0)
# Rating(user=49, product=1003, rating=2.0)
# Rating(user=62, product=68, rating=1.0)
# Rating(user=42, product=1028, rating=4.0)
# Rating(user=178, product=433, rating=4.0)
# Rating(user=85, product=51, rating=2.0)
# Rating(user=77, product=474, rating=5.0)
# Rating(user=58, product=1099, rating=2.0)
# Rating(user=56, product=1047, rating=4.0)
# Rating(user=197, product=688, rating=1.0)
# Rating(user=286, product=99, rating=4.0)
# Rating(user=90, product=258, rating=3.0)
# Rating(user=181, product=1288, rating=1.0)
# Rating(user=295, product=190, rating=4.0)
# Rating(user=224, product=69, rating=4.0)
# Rating(user=272, product=317, rating=4.0)
# Rating(user=221, product=1010, rating=3.0)
# Rating(user=66, product=877, rating=1.0)
# Rating(user=207, product=318, rating=5.0)
# Rating(user=234, product=487, rating=3.0)
# Rating(user=7, product=648, rating=5.0)
# Rating(user=87, product=82, rating=5.0)
# Rating(user=195, product=1052, rating=1.0)
# Rating(user=44, product=449, rating=5.0)
# Rating(user=306, product=287, rating=4.0)
# Rating(user=194, product=172, rating=3.0)
# Rating(user=94, product=62, rating=3.0)
# Rating(user=167, product=659, rating=4.0)
# Rating(user=108, product=100, rating=4.0)
# Rating(user=230, product=304, rating=5.0)
# Rating(user=181, product=927, rating=1.0)
# Rating(user=54, product=302, rating=4.0)
# Rating(user=90, product=22, rating=4.0)
# Rating(user=181, product=696, rating=2.0)
# Rating(user=286, product=357, rating=4.0)
# Rating(user=14, product=269, rating=4.0)
# Rating(user=311, product=179, rating=2.0)
# Rating(user=92, product=121, rating=5.0)
# Rating(user=21, product=440, rating=1.0)
# Rating(user=244, product=550, rating=1.0)
# Rating(user=181, product=405, rating=4.0)
# Rating(user=65, product=806, rating=4.0)
# Rating(user=37, product=540, rating=2.0)
# Rating(user=44, product=443, rating=5.0)
# Rating(user=244, product=183, rating=4.0)
# Rating(user=1, product=265, rating=4.0)
# Rating(user=270, product=25, rating=5.0)
# Rating(user=299, product=387, rating=2.0)
# Rating(user=94, product=572, rating=3.0)
# Rating(user=286, product=746, rating=4.0)
# Rating(user=239, product=272, rating=5.0)
# Rating(user=216, product=55, rating=5.0)
# Rating(user=254, product=121, rating=3.0)
# Rating(user=62, product=665, rating=2.0)
# Rating(user=178, product=385, rating=4.0)
# Rating(user=194, product=23, rating=4.0)
# Rating(user=268, product=955, rating=3.0)
# Rating(user=188, product=143, rating=5.0)
# Rating(user=276, product=294, rating=4.0)
# Rating(user=158, product=1098, rating=4.0)
# Rating(user=207, product=845, rating=3.0)
# Rating(user=161, product=48, rating=1.0)
# Rating(user=305, product=654, rating=4.0)
# Rating(user=47, product=324, rating=3.0)
# Rating(user=64, product=736, rating=4.0)
# Rating(user=191, product=751, rating=3.0)
# Rating(user=7, product=378, rating=5.0)
# Rating(user=59, product=92, rating=5.0)
# Rating(user=69, product=268, rating=5.0)
# Rating(user=10, product=461, rating=3.0)
# Rating(user=21, product=129, rating=4.0)
# Rating(user=58, product=9, rating=4.0)
# Rating(user=194, product=152, rating=3.0)
# Rating(user=7, product=200, rating=5.0)
# Rating(user=113, product=126, rating=5.0)
# Rating(user=173, product=328, rating=5.0)
# Rating(user=95, product=233, rating=4.0)
# Rating(user=16, product=194, rating=5.0)
# Rating(user=59, product=323, rating=4.0)
# Rating(user=311, product=654, rating=3.0)
# Rating(user=292, product=589, rating=4.0)
# Rating(user=43, product=203, rating=4.0)
# Rating(user=79, product=50, rating=4.0)
# Rating(user=235, product=70, rating=5.0)
# Rating(user=125, product=190, rating=5.0)
# Rating(user=284, product=322, rating=3.0)
# Rating(user=303, product=161, rating=5.0)
# Rating(user=254, product=378, rating=3.0)
# Rating(user=255, product=1034, rating=1.0)
# Rating(user=104, product=301, rating=2.0)
# Rating(user=90, product=923, rating=5.0)
# Rating(user=6, product=463, rating=4.0)
# Rating(user=279, product=122, rating=1.0)
# Rating(user=286, product=298, rating=4.0)
# Rating(user=222, product=448, rating=3.0)
# Rating(user=297, product=57, rating=5.0)
# Rating(user=42, product=625, rating=3.0)
# Rating(user=130, product=1217, rating=4.0)
# Rating(user=254, product=357, rating=3.0)
# Rating(user=109, product=475, rating=1.0)
# Rating(user=230, product=1444, rating=2.0)
# Rating(user=244, product=310, rating=3.0)
# Rating(user=6, product=301, rating=2.0)
# Rating(user=36, product=748, rating=4.0)
# Rating(user=256, product=443, rating=3.0)
# Rating(user=102, product=515, rating=1.0)
# Rating(user=104, product=285, rating=4.0)
# Rating(user=21, product=447, rating=5.0)
# Rating(user=111, product=301, rating=4.0)
# Rating(user=18, product=408, rating=5.0)
# Rating(user=25, product=222, rating=4.0)
# Rating(user=110, product=944, rating=3.0)
# Rating(user=270, product=98, rating=5.0)
# Rating(user=68, product=237, rating=5.0)
# Rating(user=83, product=215, rating=4.0)
# Rating(user=6, product=258, rating=2.0)
# Rating(user=89, product=216, rating=5.0)
# Rating(user=128, product=317, rating=4.0)
# Rating(user=305, product=512, rating=4.0)
# Rating(user=184, product=412, rating=2.0)
# Rating(user=286, product=175, rating=5.0)
# Rating(user=279, product=1428, rating=3.0)
# Rating(user=256, product=86, rating=5.0)
# Rating(user=221, product=48, rating=5.0)
# Rating(user=140, product=332, rating=3.0)
# Rating(user=190, product=977, rating=2.0)
# Rating(user=11, product=227, rating=3.0)
# Rating(user=201, product=203, rating=5.0)
# Rating(user=150, product=181, rating=5.0)
# Rating(user=126, product=245, rating=3.0)
# Rating(user=20, product=208, rating=2.0)
# Rating(user=144, product=742, rating=4.0)
# Rating(user=181, product=930, rating=1.0)
# Rating(user=109, product=566, rating=4.0)
# Rating(user=85, product=1065, rating=3.0)
# Rating(user=213, product=133, rating=3.0)
# Rating(user=222, product=379, rating=1.0)
# Rating(user=223, product=11, rating=3.0)
# Rating(user=215, product=421, rating=4.0)
# Rating(user=218, product=208, rating=3.0)
# Rating(user=174, product=937, rating=5.0)
# Rating(user=275, product=186, rating=3.0)
# Rating(user=68, product=742, rating=1.0)
# Rating(user=268, product=583, rating=4.0)
# Rating(user=160, product=462, rating=4.0)
# Rating(user=195, product=273, rating=4.0)
# Rating(user=224, product=178, rating=4.0)
# Rating(user=5, product=110, rating=1.0)
# Rating(user=99, product=1016, rating=5.0)
# Rating(user=2, product=251, rating=5.0)
# Rating(user=292, product=9, rating=4.0)
# Rating(user=72, product=568, rating=4.0)
# Rating(user=85, product=228, rating=3.0)
# Rating(user=83, product=281, rating=5.0)
# Rating(user=92, product=831, rating=2.0)
# Rating(user=7, product=543, rating=3.0)
# Rating(user=87, product=401, rating=2.0)
# Rating(user=287, product=926, rating=4.0)
# Rating(user=1, product=155, rating=2.0)
# Rating(user=234, product=632, rating=2.0)
# Rating(user=222, product=53, rating=5.0)
# Rating(user=24, product=64, rating=5.0)
# Rating(user=7, product=554, rating=3.0)
# Rating(user=82, product=56, rating=3.0)
# Rating(user=161, product=318, rating=3.0)
# Rating(user=196, product=393, rating=4.0)
# Rating(user=56, product=91, rating=4.0)
# Rating(user=82, product=477, rating=3.0)
# Rating(user=7, product=472, rating=2.0)
# Rating(user=256, product=761, rating=4.0)
# Rating(user=226, product=56, rating=4.0)
# Rating(user=279, product=741, rating=5.0)
# Rating(user=308, product=1286, rating=3.0)
# Rating(user=16, product=8, rating=5.0)
# Rating(user=180, product=202, rating=3.0)
# Rating(user=203, product=93, rating=4.0)
# Rating(user=145, product=56, rating=5.0)
# Rating(user=288, product=305, rating=4.0)
# Rating(user=84, product=742, rating=3.0)
# Rating(user=44, product=644, rating=3.0)
# Rating(user=17, product=13, rating=3.0)
# Rating(user=313, product=117, rating=4.0)
# Rating(user=148, product=1, rating=4.0)
# Rating(user=197, product=347, rating=4.0)
# Rating(user=21, product=164, rating=5.0)
# Rating(user=279, product=982, rating=3.0)
# Rating(user=239, product=491, rating=5.0)
# Rating(user=185, product=287, rating=5.0)
# Rating(user=297, product=89, rating=4.0)
# Rating(user=303, product=68, rating=4.0)
# Rating(user=186, product=250, rating=1.0)
# Rating(user=73, product=206, rating=3.0)
# Rating(user=104, product=756, rating=2.0)
# Rating(user=94, product=216, rating=3.0)
# Rating(user=239, product=194, rating=5.0)
# Rating(user=197, product=511, rating=5.0)
# Rating(user=280, product=1, rating=4.0)
# Rating(user=1, product=117, rating=3.0)
# Rating(user=224, product=583, rating=1.0)
# Rating(user=303, product=397, rating=1.0)
# Rating(user=60, product=162, rating=4.0)
# Rating(user=198, product=258, rating=4.0)
# Rating(user=239, product=513, rating=5.0)
# Rating(user=6, product=69, rating=3.0)
# Rating(user=233, product=375, rating=4.0)
# Rating(user=85, product=642, rating=4.0)
# Rating(user=110, product=38, rating=3.0)
# Rating(user=184, product=522, rating=3.0)
# Rating(user=99, product=873, rating=1.0)
# Rating(user=13, product=418, rating=2.0)
# Rating(user=201, product=518, rating=4.0)
# Rating(user=13, product=858, rating=1.0)
# Rating(user=214, product=131, rating=3.0)
# Rating(user=296, product=228, rating=4.0)
# Rating(user=222, product=87, rating=3.0)
# Rating(user=279, product=725, rating=4.0)
# Rating(user=217, product=182, rating=2.0)
# Rating(user=85, product=433, rating=3.0)
# Rating(user=239, product=234, rating=3.0)
# Rating(user=13, product=72, rating=4.0)
# Rating(user=194, product=77, rating=3.0)
# Rating(user=208, product=663, rating=5.0)
# Rating(user=109, product=178, rating=3.0)
# Rating(user=230, product=172, rating=4.0)
# Rating(user=59, product=485, rating=2.0)
# Rating(user=313, product=478, rating=3.0)
# Rating(user=70, product=1133, rating=3.0)
# Rating(user=62, product=182, rating=5.0)
# Rating(user=198, product=234, rating=3.0)
# Rating(user=65, product=125, rating=4.0)
# Rating(user=174, product=660, rating=5.0)
# Rating(user=90, product=12, rating=5.0)
# Rating(user=130, product=1248, rating=3.0)
# Rating(user=100, product=354, rating=2.0)
# Rating(user=283, product=432, rating=5.0)
# Rating(user=275, product=418, rating=3.0)
# Rating(user=311, product=98, rating=5.0)
# Rating(user=195, product=751, rating=4.0)
# Rating(user=130, product=105, rating=4.0)
# Rating(user=269, product=252, rating=1.0)
# Rating(user=286, product=73, rating=5.0)
# Rating(user=7, product=623, rating=3.0)
# Rating(user=56, product=222, rating=5.0)
# Rating(user=210, product=204, rating=5.0)
# Rating(user=239, product=9, rating=5.0)
# Rating(user=96, product=87, rating=4.0)
# Rating(user=297, product=73, rating=2.0)
# Rating(user=249, product=239, rating=3.0)
# Rating(user=94, product=860, rating=2.0)
# Rating(user=84, product=121, rating=4.0)
# Rating(user=275, product=265, rating=4.0)
# Rating(user=135, product=1046, rating=3.0)
# Rating(user=291, product=1178, rating=4.0)
# Rating(user=125, product=382, rating=1.0)
# Rating(user=70, product=399, rating=4.0)
# Rating(user=311, product=9, rating=4.0)
# Rating(user=301, product=523, rating=4.0)
# Rating(user=152, product=685, rating=5.0)
# Rating(user=244, product=172, rating=4.0)
# Rating(user=275, product=1091, rating=2.0)
# Rating(user=53, product=281, rating=4.0)
# Rating(user=198, product=118, rating=2.0)
# Rating(user=244, product=790, rating=4.0)
# Rating(user=26, product=125, rating=4.0)
# Rating(user=151, product=13, rating=3.0)
# Rating(user=124, product=496, rating=1.0)
# Rating(user=24, product=191, rating=5.0)
# Rating(user=271, product=65, rating=3.0)
# Rating(user=307, product=634, rating=3.0)
# Rating(user=294, product=1245, rating=3.0)
# Rating(user=234, product=241, rating=2.0)
# Rating(user=25, product=501, rating=3.0)
# Rating(user=293, product=137, rating=3.0)
# Rating(user=201, product=432, rating=3.0)
# Rating(user=75, product=240, rating=1.0)
# Rating(user=13, product=181, rating=5.0)
# Rating(user=207, product=68, rating=2.0)
# Rating(user=2, product=50, rating=5.0)
# Rating(user=313, product=566, rating=4.0)
# Rating(user=144, product=125, rating=4.0)
# Rating(user=188, product=443, rating=4.0)
# Rating(user=276, product=324, rating=4.0)
# Rating(user=145, product=974, rating=1.0)
# Rating(user=72, product=234, rating=4.0)
# Rating(user=83, product=385, rating=4.0)
# Rating(user=181, product=619, rating=3.0)
# Rating(user=109, product=402, rating=4.0)
# Rating(user=207, product=107, rating=3.0)
# Rating(user=185, product=216, rating=4.0)
# Rating(user=14, product=213, rating=5.0)
# Rating(user=149, product=319, rating=2.0)
# Rating(user=57, product=79, rating=5.0)
# Rating(user=230, product=963, rating=5.0)
# Rating(user=176, product=875, rating=4.0)
# Rating(user=253, product=97, rating=4.0)
# Rating(user=284, product=269, rating=4.0)
# Rating(user=106, product=526, rating=4.0)
# Rating(user=121, product=180, rating=3.0)
# Rating(user=62, product=86, rating=2.0)
# Rating(user=291, product=418, rating=4.0)
# Rating(user=84, product=1033, rating=4.0)
# Rating(user=293, product=380, rating=2.0)
# Rating(user=207, product=58, rating=3.0)
# Rating(user=194, product=187, rating=4.0)
# Rating(user=109, product=97, rating=3.0)
# Rating(user=283, product=845, rating=4.0)
# Rating(user=297, product=275, rating=5.0)
# Rating(user=181, product=334, rating=1.0)
# Rating(user=78, product=255, rating=4.0)
# Rating(user=11, product=425, rating=4.0)
# Rating(user=308, product=59, rating=4.0)
# Rating(user=193, product=1078, rating=4.0)
# Rating(user=297, product=234, rating=3.0)
# Rating(user=87, product=585, rating=4.0)
# Rating(user=250, product=204, rating=2.0)
# Rating(user=8, product=50, rating=5.0)
# Rating(user=186, product=148, rating=4.0)
# Rating(user=312, product=692, rating=4.0)
# Rating(user=91, product=683, rating=3.0)
# Rating(user=5, product=454, rating=1.0)
# Rating(user=291, product=376, rating=3.0)
# Rating(user=175, product=127, rating=5.0)
# Rating(user=145, product=737, rating=2.0)
# Rating(user=7, product=644, rating=5.0)
# Rating(user=276, product=419, rating=5.0)
# Rating(user=83, product=210, rating=5.0)
# Rating(user=102, product=524, rating=3.0)
# Rating(user=153, product=174, rating=1.0)
# Rating(user=62, product=302, rating=3.0)
# Rating(user=49, product=995, rating=3.0)
# Rating(user=268, product=298, rating=3.0)
# Rating(user=207, product=554, rating=2.0)
# Rating(user=313, product=616, rating=5.0)
# Rating(user=286, product=44, rating=3.0)
# Rating(user=279, product=168, rating=5.0)
# Rating(user=276, product=474, rating=5.0)
# Rating(user=62, product=59, rating=4.0)
# Rating(user=254, product=219, rating=1.0)
# Rating(user=83, product=97, rating=4.0)
# Rating(user=63, product=100, rating=5.0)
# Rating(user=16, product=178, rating=5.0)
# Rating(user=297, product=233, rating=2.0)
# Rating(user=90, product=945, rating=5.0)
# Rating(user=85, product=25, rating=2.0)
# Rating(user=42, product=98, rating=4.0)
# Rating(user=303, product=393, rating=4.0)
# Rating(user=274, product=50, rating=5.0)
# Rating(user=104, product=299, rating=3.0)
# Rating(user=94, product=792, rating=4.0)
# Rating(user=184, product=98, rating=4.0)
# Rating(user=293, product=708, rating=3.0)
# Rating(user=248, product=589, rating=4.0)
# Rating(user=18, product=950, rating=3.0)
# Rating(user=217, product=27, rating=1.0)
# Rating(user=200, product=892, rating=4.0)
# Rating(user=201, product=148, rating=1.0)
# Rating(user=296, product=222, rating=5.0)
# Rating(user=7, product=662, rating=3.0)
# Rating(user=196, product=381, rating=4.0)
# Rating(user=69, product=427, rating=3.0)
# Rating(user=72, product=196, rating=4.0)
# Rating(user=256, product=472, rating=4.0)
# Rating(user=128, product=182, rating=4.0)
# Rating(user=151, product=747, rating=3.0)
# Rating(user=7, product=171, rating=3.0)
# Rating(user=286, product=85, rating=5.0)
# Rating(user=172, product=220, rating=4.0)
# Rating(user=308, product=516, rating=4.0)
# Rating(user=190, product=974, rating=2.0)
# Rating(user=82, product=756, rating=1.0)
# Rating(user=308, product=436, rating=4.0)
# Rating(user=59, product=235, rating=1.0)
# Rating(user=64, product=1063, rating=3.0)
# Rating(user=145, product=756, rating=2.0)
# Rating(user=220, product=298, rating=4.0)
# Rating(user=21, product=324, rating=4.0)
# Rating(user=285, product=269, rating=4.0)
# Rating(user=207, product=65, rating=3.0)
# Rating(user=198, product=658, rating=3.0)
# Rating(user=220, product=333, rating=3.0)
# Rating(user=210, product=70, rating=4.0)
# ...
# Rating(user=708, product=762, rating=5.0)
# Rating(user=928, product=9, rating=5.0)
# Rating(user=535, product=7, rating=5.0)
# Rating(user=881, product=566, rating=4.0)
# Rating(user=870, product=943, rating=2.0)
# Rating(user=707, product=505, rating=4.0)
# Rating(user=717, product=591, rating=4.0)
# Rating(user=847, product=685, rating=2.0)
# Rating(user=892, product=1444, rating=3.0)
# Rating(user=820, product=895, rating=2.0)
# Rating(user=334, product=47, rating=4.0)
# Rating(user=209, product=276, rating=2.0)
# Rating(user=495, product=1039, rating=5.0)
# Rating(user=786, product=1, rating=4.0)
# Rating(user=318, product=340, rating=4.0)
# Rating(user=465, product=408, rating=5.0)
# Rating(user=552, product=281, rating=3.0)
# Rating(user=867, product=294, rating=3.0)
# Rating(user=936, product=1226, rating=3.0)
# Rating(user=871, product=904, rating=3.0)
# Rating(user=903, product=405, rating=4.0)
# Rating(user=901, product=447, rating=3.0)
# Rating(user=934, product=419, rating=4.0)
# Rating(user=862, product=208, rating=2.0)
# Rating(user=59, product=273, rating=2.0)
# Rating(user=886, product=50, rating=5.0)
# Rating(user=912, product=427, rating=5.0)
# Rating(user=798, product=924, rating=3.0)
# Rating(user=892, product=131, rating=4.0)
# Rating(user=339, product=212, rating=4.0)
# Rating(user=909, product=224, rating=5.0)
# Rating(user=897, product=174, rating=5.0)
# Rating(user=593, product=58, rating=4.0)
# Rating(user=354, product=319, rating=3.0)
# Rating(user=64, product=184, rating=4.0)
# Rating(user=889, product=181, rating=4.0)
# Rating(user=798, product=443, rating=3.0)
# Rating(user=901, product=15, rating=5.0)
# Rating(user=830, product=834, rating=1.0)
# Rating(user=773, product=895, rating=2.0)
# Rating(user=528, product=410, rating=4.0)
# Rating(user=271, product=169, rating=5.0)
# Rating(user=346, product=151, rating=4.0)
# Rating(user=838, product=993, rating=3.0)
# Rating(user=698, product=134, rating=3.0)
# Rating(user=238, product=151, rating=2.0)
# Rating(user=474, product=31, rating=4.0)
# Rating(user=642, product=73, rating=4.0)
# Rating(user=870, product=11, rating=4.0)
# Rating(user=643, product=39, rating=4.0)
# Rating(user=887, product=98, rating=3.0)
# Rating(user=846, product=40, rating=2.0)
# Rating(user=846, product=98, rating=4.0)
# Rating(user=503, product=692, rating=3.0)
# Rating(user=898, product=302, rating=4.0)
# Rating(user=916, product=557, rating=4.0)
# Rating(user=896, product=751, rating=4.0)
# Rating(user=918, product=747, rating=3.0)
# Rating(user=664, product=660, rating=3.0)
# Rating(user=935, product=120, rating=3.0)
# Rating(user=766, product=498, rating=4.0)
# Rating(user=806, product=170, rating=5.0)
# Rating(user=907, product=278, rating=5.0)
# Rating(user=588, product=265, rating=5.0)
# Rating(user=805, product=128, rating=5.0)
# Rating(user=931, product=546, rating=3.0)
# Rating(user=554, product=181, rating=4.0)
# Rating(user=913, product=28, rating=3.0)
# Rating(user=820, product=751, rating=1.0)
# Rating(user=896, product=176, rating=5.0)
# Rating(user=306, product=741, rating=1.0)
# Rating(user=533, product=265, rating=3.0)
# Rating(user=939, product=237, rating=5.0)
# Rating(user=782, product=351, rating=3.0)
# Rating(user=738, product=135, rating=5.0)
# Rating(user=790, product=1077, rating=3.0)
# Rating(user=875, product=22, rating=3.0)
# Rating(user=83, product=245, rating=2.0)
# Rating(user=870, product=508, rating=3.0)
# Rating(user=787, product=268, rating=4.0)
# Rating(user=574, product=358, rating=2.0)
# Rating(user=303, product=627, rating=3.0)
# Rating(user=815, product=526, rating=4.0)
# Rating(user=621, product=384, rating=3.0)
# Rating(user=43, product=591, rating=5.0)
# Rating(user=43, product=123, rating=1.0)
# Rating(user=800, product=1, rating=4.0)
# Rating(user=847, product=120, rating=1.0)
# Rating(user=880, product=3, rating=1.0)
# Rating(user=518, product=405, rating=5.0)
# Rating(user=655, product=872, rating=3.0)
# Rating(user=712, product=1480, rating=4.0)
# Rating(user=25, product=176, rating=4.0)
# Rating(user=886, product=11, rating=5.0)
# Rating(user=890, product=157, rating=4.0)
# Rating(user=694, product=188, rating=5.0)
# Rating(user=881, product=732, rating=5.0)
# Rating(user=496, product=660, rating=3.0)
# Rating(user=749, product=444, rating=2.0)
# Rating(user=388, product=53, rating=5.0)
# Rating(user=704, product=340, rating=3.0)
# Rating(user=781, product=179, rating=5.0)
# Rating(user=682, product=71, rating=5.0)
# Rating(user=451, product=876, rating=4.0)
# Rating(user=474, product=56, rating=5.0)
# Rating(user=422, product=267, rating=4.0)
# Rating(user=920, product=272, rating=3.0)
# Rating(user=707, product=52, rating=3.0)
# Rating(user=741, product=151, rating=3.0)
# Rating(user=715, product=143, rating=3.0)
# Rating(user=870, product=4, rating=2.0)
# Rating(user=619, product=79, rating=5.0)
# Rating(user=648, product=281, rating=3.0)
# Rating(user=933, product=96, rating=2.0)
# Rating(user=746, product=228, rating=4.0)
# Rating(user=872, product=1284, rating=3.0)
# Rating(user=525, product=106, rating=2.0)
# Rating(user=691, product=496, rating=5.0)
# Rating(user=140, product=303, rating=5.0)
# Rating(user=327, product=498, rating=4.0)
# Rating(user=32, product=408, rating=3.0)
# Rating(user=892, product=208, rating=4.0)
# Rating(user=840, product=480, rating=5.0)
# Rating(user=98, product=194, rating=5.0)
# Rating(user=518, product=410, rating=3.0)
# Rating(user=798, product=202, rating=2.0)
# Rating(user=814, product=5, rating=3.0)
# Rating(user=577, product=181, rating=5.0)
# Rating(user=869, product=1047, rating=2.0)
# Rating(user=843, product=132, rating=3.0)
# Rating(user=472, product=420, rating=3.0)
# Rating(user=399, product=1542, rating=2.0)
# Rating(user=924, product=471, rating=4.0)
# Rating(user=474, product=124, rating=5.0)
# Rating(user=892, product=157, rating=5.0)
# Rating(user=939, product=471, rating=5.0)
# Rating(user=862, product=485, rating=5.0)
# Rating(user=495, product=573, rating=4.0)
# Rating(user=405, product=958, rating=1.0)
# Rating(user=749, product=712, rating=3.0)
# Rating(user=807, product=204, rating=4.0)
# Rating(user=721, product=242, rating=3.0)
# Rating(user=868, product=172, rating=5.0)
# Rating(user=854, product=290, rating=1.0)
# Rating(user=839, product=1381, rating=3.0)
# Rating(user=902, product=187, rating=3.0)
# Rating(user=864, product=418, rating=3.0)
# Rating(user=862, product=205, rating=4.0)
# Rating(user=766, product=428, rating=5.0)
# Rating(user=603, product=56, rating=4.0)
# Rating(user=789, product=124, rating=4.0)
# Rating(user=826, product=260, rating=3.0)
# Rating(user=18, product=967, rating=3.0)
# Rating(user=907, product=815, rating=5.0)
# Rating(user=450, product=654, rating=4.0)
# Rating(user=665, product=378, rating=3.0)
# Rating(user=854, product=528, rating=4.0)
# Rating(user=378, product=441, rating=3.0)
# Rating(user=880, product=110, rating=3.0)
# Rating(user=532, product=425, rating=4.0)
# Rating(user=851, product=553, rating=4.0)
# Rating(user=633, product=159, rating=4.0)
# Rating(user=653, product=135, rating=5.0)
# Rating(user=348, product=596, rating=4.0)
# Rating(user=749, product=205, rating=4.0)
# Rating(user=934, product=786, rating=1.0)
# Rating(user=806, product=875, rating=3.0)
# Rating(user=524, product=481, rating=4.0)
# Rating(user=860, product=732, rating=4.0)
# Rating(user=721, product=263, rating=3.0)
# Rating(user=618, product=531, rating=4.0)
# Rating(user=903, product=544, rating=2.0)
# Rating(user=737, product=22, rating=4.0)
# Rating(user=752, product=268, rating=2.0)
# Rating(user=897, product=523, rating=5.0)
# Rating(user=56, product=575, rating=3.0)
# Rating(user=865, product=743, rating=1.0)
# Rating(user=886, product=2, rating=4.0)
# Rating(user=781, product=210, rating=4.0)
# Rating(user=849, product=625, rating=5.0)
# Rating(user=606, product=576, rating=3.0)
# Rating(user=303, product=939, rating=3.0)
# Rating(user=870, product=435, rating=3.0)
# Rating(user=13, product=446, rating=1.0)
# Rating(user=747, product=124, rating=5.0)
# Rating(user=204, product=333, rating=1.0)
# Rating(user=925, product=558, rating=1.0)
# Rating(user=878, product=155, rating=3.0)
# Rating(user=880, product=5, rating=3.0)
# Rating(user=916, product=356, rating=3.0)
# Rating(user=188, product=484, rating=5.0)
# Rating(user=846, product=101, rating=4.0)
# Rating(user=389, product=133, rating=5.0)
# Rating(user=879, product=596, rating=2.0)
# Rating(user=840, product=432, rating=5.0)
# Rating(user=626, product=680, rating=1.0)
# Rating(user=804, product=233, rating=4.0)
# Rating(user=663, product=240, rating=3.0)
# Rating(user=145, product=769, rating=2.0)
# Rating(user=818, product=313, rating=4.0)
# Rating(user=574, product=328, rating=3.0)
# Rating(user=648, product=456, rating=2.0)
# Rating(user=806, product=169, rating=5.0)
# Rating(user=666, product=265, rating=3.0)
# Rating(user=794, product=100, rating=5.0)
# Rating(user=303, product=1086, rating=1.0)
# Rating(user=933, product=441, rating=2.0)
# Rating(user=519, product=887, rating=5.0)
# Rating(user=867, product=172, rating=5.0)
# Rating(user=889, product=550, rating=3.0)
# Rating(user=938, product=993, rating=5.0)
# Rating(user=532, product=990, rating=3.0)
# Rating(user=487, product=313, rating=3.0)
# Rating(user=659, product=216, rating=4.0)
# Rating(user=943, product=739, rating=4.0)
# Rating(user=416, product=153, rating=4.0)
# Rating(user=864, product=151, rating=5.0)
# Rating(user=932, product=416, rating=3.0)
# Rating(user=734, product=294, rating=1.0)
# Rating(user=874, product=275, rating=4.0)
# Rating(user=903, product=1381, rating=4.0)
# Rating(user=303, product=363, rating=1.0)
# Rating(user=921, product=25, rating=3.0)
# Rating(user=788, product=157, rating=5.0)
# Rating(user=634, product=1028, rating=3.0)
# Rating(user=916, product=148, rating=2.0)
# Rating(user=892, product=631, rating=4.0)
# Rating(user=401, product=405, rating=2.0)
# Rating(user=10, product=198, rating=3.0)
# Rating(user=689, product=258, rating=5.0)
# Rating(user=5, product=174, rating=5.0)
# Rating(user=891, product=978, rating=4.0)
# Rating(user=921, product=143, rating=5.0)
# Rating(user=23, product=227, rating=3.0)
# Rating(user=848, product=216, rating=5.0)
# Rating(user=739, product=50, rating=4.0)
# Rating(user=869, product=282, rating=3.0)
# Rating(user=747, product=510, rating=5.0)
# Rating(user=913, product=318, rating=4.0)
# Rating(user=835, product=588, rating=3.0)
# Rating(user=723, product=9, rating=3.0)
# Rating(user=935, product=685, rating=4.0)
# Rating(user=537, product=675, rating=3.0)
# Rating(user=694, product=705, rating=5.0)
# Rating(user=937, product=294, rating=1.0)
# Rating(user=707, product=864, rating=4.0)
# Rating(user=899, product=200, rating=4.0)
# Rating(user=561, product=611, rating=5.0)
# Rating(user=826, product=748, rating=4.0)
# Rating(user=773, product=232, rating=3.0)
# Rating(user=749, product=823, rating=3.0)
# Rating(user=806, product=90, rating=4.0)
# Rating(user=884, product=463, rating=5.0)
# Rating(user=707, product=708, rating=3.0)
# Rating(user=535, product=1170, rating=3.0)
# Rating(user=383, product=200, rating=5.0)
# Rating(user=903, product=651, rating=5.0)
# Rating(user=887, product=274, rating=1.0)
# Rating(user=484, product=210, rating=5.0)
# Rating(user=715, product=778, rating=2.0)
# Rating(user=879, product=111, rating=4.0)
# Rating(user=710, product=79, rating=4.0)
# Rating(user=711, product=48, rating=4.0)
# Rating(user=669, product=479, rating=5.0)
# Rating(user=684, product=248, rating=3.0)
# Rating(user=407, product=7, rating=4.0)
# Rating(user=889, product=8, rating=3.0)
# Rating(user=619, product=578, rating=4.0)
# Rating(user=485, product=752, rating=3.0)
# Rating(user=393, product=613, rating=4.0)
# Rating(user=853, product=333, rating=4.0)
# Rating(user=887, product=1063, rating=1.0)
# Rating(user=838, product=313, rating=5.0)
# Rating(user=447, product=770, rating=3.0)
# Rating(user=527, product=659, rating=4.0)
# Rating(user=606, product=97, rating=5.0)
# Rating(user=630, product=815, rating=3.0)
# Rating(user=806, product=209, rating=3.0)
# Rating(user=867, product=748, rating=4.0)
# Rating(user=693, product=1136, rating=3.0)
# Rating(user=648, product=318, rating=3.0)
# Rating(user=875, product=964, rating=4.0)
# Rating(user=749, product=636, rating=4.0)
# Rating(user=490, product=109, rating=5.0)
# Rating(user=441, product=282, rating=4.0)
# Rating(user=851, product=1013, rating=2.0)
# Rating(user=883, product=234, rating=4.0)
# Rating(user=102, product=7, rating=2.0)
# Rating(user=896, product=96, rating=5.0)
# Rating(user=935, product=117, rating=4.0)
# Rating(user=358, product=1005, rating=4.0)
# Rating(user=874, product=286, rating=4.0)
# Rating(user=896, product=511, rating=5.0)
# Rating(user=828, product=531, rating=4.0)
# Rating(user=835, product=174, rating=5.0)
# Rating(user=593, product=223, rating=5.0)
# Rating(user=904, product=173, rating=3.0)
# Rating(user=764, product=281, rating=3.0)
# Rating(user=741, product=696, rating=3.0)
# Rating(user=930, product=410, rating=3.0)
# Rating(user=798, product=659, rating=4.0)
# Rating(user=211, product=215, rating=5.0)
# Rating(user=554, product=172, rating=5.0)
# Rating(user=659, product=657, rating=5.0)
# Rating(user=931, product=257, rating=4.0)
# Rating(user=221, product=144, rating=4.0)
# Rating(user=207, product=173, rating=3.0)
# Rating(user=936, product=251, rating=4.0)
# Rating(user=868, product=405, rating=1.0)
# Rating(user=102, product=172, rating=3.0)
# Rating(user=903, product=50, rating=5.0)
# Rating(user=653, product=411, rating=2.0)
# Rating(user=895, product=100, rating=4.0)
# Rating(user=379, product=621, rating=4.0)
# Rating(user=130, product=824, rating=3.0)
# Rating(user=929, product=276, rating=2.0)
# Rating(user=788, product=328, rating=4.0)
# Rating(user=577, product=176, rating=5.0)
# Rating(user=725, product=276, rating=4.0)
# Rating(user=851, product=1337, rating=3.0)
# Rating(user=889, product=77, rating=3.0)
# Rating(user=780, product=313, rating=5.0)
# Rating(user=828, product=346, rating=4.0)
# Rating(user=593, product=1, rating=3.0)
# Rating(user=363, product=181, rating=5.0)
# Rating(user=925, product=200, rating=2.0)
# Rating(user=862, product=120, rating=3.0)
# Rating(user=848, product=708, rating=4.0)
# Rating(user=563, product=566, rating=4.0)
# Rating(user=500, product=1010, rating=4.0)
# Rating(user=780, product=50, rating=5.0)
# Rating(user=823, product=134, rating=5.0)
# Rating(user=130, product=93, rating=5.0)
# Rating(user=130, product=121, rating=5.0)
# Rating(user=537, product=778, rating=3.0)
# Rating(user=655, product=913, rating=4.0)
# Rating(user=889, product=2, rating=3.0)
# Rating(user=865, product=1009, rating=5.0)
# Rating(user=851, product=979, rating=3.0)
# Rating(user=833, product=474, rating=5.0)
# Rating(user=394, product=380, rating=4.0)
# Rating(user=193, product=690, rating=4.0)
# Rating(user=621, product=809, rating=4.0)
# Rating(user=766, product=91, rating=5.0)
# Rating(user=650, product=479, rating=5.0)
# Rating(user=429, product=199, rating=5.0)
# Rating(user=847, product=596, rating=3.0)
# Rating(user=934, product=216, rating=1.0)
# Rating(user=788, product=556, rating=2.0)
# Rating(user=897, product=369, rating=4.0)
# Rating(user=936, product=287, rating=4.0)
# Rating(user=936, product=766, rating=3.0)
# Rating(user=449, product=120, rating=1.0)
# Rating(user=661, product=762, rating=2.0)
# Rating(user=721, product=874, rating=3.0)
# Rating(user=821, product=151, rating=4.0)
# Rating(user=764, product=596, rating=3.0)
# Rating(user=537, product=443, rating=3.0)
# Rating(user=618, product=628, rating=2.0)
# Rating(user=487, product=291, rating=3.0)
# Rating(user=113, product=975, rating=5.0)
# Rating(user=943, product=391, rating=2.0)
# Rating(user=864, product=685, rating=4.0)
# Rating(user=750, product=323, rating=3.0)
# Rating(user=279, product=64, rating=1.0)
# Rating(user=646, product=750, rating=3.0)
# Rating(user=654, product=370, rating=2.0)
# Rating(user=617, product=582, rating=4.0)
# Rating(user=913, product=690, rating=3.0)
# Rating(user=660, product=229, rating=2.0)
# Rating(user=421, product=498, rating=4.0)
# Rating(user=495, product=1091, rating=4.0)
# Rating(user=806, product=421, rating=4.0)
# Rating(user=676, product=538, rating=4.0)
# Rating(user=721, product=262, rating=3.0)
# Rating(user=913, product=209, rating=2.0)
# Rating(user=378, product=78, rating=3.0)
# Rating(user=880, product=476, rating=3.0)
# Rating(user=716, product=204, rating=5.0)
# Rating(user=276, product=1090, rating=1.0)
# Rating(user=13, product=225, rating=2.0)
# Rating(user=12, product=203, rating=3.0)

# %% [markdown]
# # 2.	Build a recommendation model using Alternating Least Squares.

# %%
# Build the recommendation model using Alternating Least Squares
rank = 10
numIterations = 10
model = ALS.train(ratings, rank, numIterations)

# %%
# Evaluate the model on training data
testdata = ratings.map(lambda p: (p[0], p[1]))
predictions = model.predictAll(testdata).map(lambda r: ((r[0], r[1]), r[2]))
ratesAndPreds = ratings.map(lambda r: ((r[0], r[1]), r[2])).join(predictions)

# %% [markdown]
# # 3.	Report the original performance (Mean Squared Error)

# %%
MSE = ratesAndPreds.map(lambda r: (r[1][0] - r[1][1])**2).mean()
print("Mean Squared Error = " + str(MSE))
# Out:
# Mean Squared Error = 0.48248691362843

# %% [markdown]
# # 4.	Try to improve the performance of the original model using 10-fold cross validation and solve the cold-start problem.
#
# #### Used  CrossValidator(estimator = als, evaluator = evaluator, numFolds = 10) to add  10-fold cross validation
# #### Used coldStartStrategy="drop" to solve the cold-start problem by setting cold start strategy to 'drop' to ensure we don't get NaN evaluation metrics

# %% [markdown]
# # 5.	Optimize the model based on step 4 and report the improvement of performance.

# %%
from pyspark.ml.tuning import CrossValidator   # To add k-fold cross validation
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import ParamGridBuilder

param_grid = ParamGridBuilder().addGrid(als.rank, [5, 40, 80, 120]).addGrid(als.maxIter, [5, 100, 250, 500]).addGrid(als.regParam, [.05, .1, 1.5]).build()

# Here used 5 max iterations and set cold start strategy to 'drop' to ensure we don't get NaN evaluation metrics
als = ALS(maxIter=5, regParam=0.01, userCol="user", itemCol="product", ratingCol="rating",coldStartStrategy="drop")

lines = spark.read.text("u.data").rdd
parts = lines.map(lambda row: row.value.split("\t"))

parts_list = parts.collect()
ratingsRDD = parts.map(lambda p: Rating(int(p[0]), int(p[1]), float(p[2])))
ratings = spark.createDataFrame(ratingsRDD)

(training, test) = ratings.randomSplit([0.8, 0.2])

# Tell Spark how to evaluate model performance
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",predictionCol="prediction")

# Build cross validation step using CrossValidator
cv = CrossValidator(estimator = als, estimatorParamMaps = param_grid, evaluator = evaluator, numFolds = 10)

model = cv.fit(training)      # Run the cv on the training data

best_model = model.bestModel  # Extract best combination of values from cross validation

# %%
# Evaluate the model by computing the RMSE on the test data
predictions = best_model.transform(test)
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
rmse = evaluator.evaluate(predictions)
print("RMSE after optimization = " + str(rmse))
# Out:
# RMSE after optimization = 1.0705761552239235

# %% [markdown]
# ## 6.	Output top 10 movies for all the users with the following format:

# %%
# Generate top 10 movie recommendations for each user
userRecs = best_model.recommendForAllUsers(10)

def get_used_id_and_corresponding_recommendations(x):
    user_id = x.user
    recommendations = x.recommendations
    return (user_id, recommendations)

rdd2 = userRecs.rdd.map(lambda x: get_used_id_and_corresponding_recommendations(x))

# %%
## Process the spark dataframe for top 10 movie recommendations for each user and create the string to write to output file

used_id_recommendations = rdd2.collect()

final_str = ""
for line in used_id_recommendations:
    row_str = ""
    user_id = line[0]
    row_str = str(user_id) + "\t"
    recommendations = line[1]
    recommendation_movie_list = []
    for recommendation in recommendations:
        recommendation_movie_list.append(str(recommendation.product))
    row_str += ",". join(recommendation_movie_list)
    print (row_str)
    final_str = final_str + row_str + "\n"
    
final_str = final_str.strip()
# Out:
# 1	865,793,896,1643,1252,745,1449,1585,958,915
# 3	1401,1093,320,914,1368,361,906,1160,344,980
# 6	1643,998,1380,1368,1463,1512,1449,1126,361,1114
# 12	960,1664,793,1169,791,341,745,296,904,1121
# 13	1266,1192,1367,745,1019,1607,1311,1463,1643,1142
# 16	1015,1451,1428,1205,1169,592,641,1199,115,612
# 20	975,1159,1192,697,601,867,1266,360,263,974
# 22	793,1160,1252,1159,896,958,108,798,915,1514
# 26	1643,1260,1449,1463,320,867,1024,1642,1159,1194
# 27	1286,1512,1368,1131,1434,1176,867,1257,262,1024
# 28	1245,865,253,361,1084,1240,1268,1643,1631,695
# 31	1085,1456,1116,1245,848,791,641,81,1204,361
# 34	1094,621,1288,1192,987,1266,775,1297,1426,909
# 801	344,1368,320,1185,1643,1512,913,962,1288,1265
# 802	1245,1240,853,1142,634,865,532,916,980,745
# 803	960,1426,865,6,1172,592,947,1558,793,753
# 805	865,1643,1368,361,1245,262,1631,1449,1154,718
# 807	1218,634,1093,1313,256,1314,908,680,34,1463
# 809	960,1426,862,1512,1173,1172,1120,883,733,481
# 815	1426,958,793,862,592,960,811,1153,703,745
# 816	916,791,1245,1169,980,1166,1240,206,634,309
# 818	865,1268,791,960,1456,1631,1434,352,516,253
# 820	1154,764,1054,697,1475,865,1297,621,1086,500
# 825	1169,1446,634,1483,34,309,1166,727,1301,791
# 828	1426,902,896,1298,865,1094,1159,1163,1311,1019
# 832	1054,1503,899,1159,1220,853,1163,745,965,869
# 835	1512,6,1167,793,960,1131,1368,1121,1463,1643
# 837	1160,1252,793,1150,1254,1167,1113,904,1234,828
# 841	1166,1278,574,698,34,344,1286,1221,555,1265
# 851	1643,1449,1463,1159,1169,745,1084,1122,1007,1368
# 859	75,1240,865,1160,767,853,1154,1159,532,1245
# 863	865,1240,1298,583,774,1514,1159,853,1160,914
# 864	1643,361,1631,1131,1463,793,1368,296,1585,865
# 865	1205,899,838,1368,320,543,1150,914,583,537
# 866	1288,1368,320,1411,1066,1252,1260,1024,1097,1207
# 872	1160,774,1159,1163,838,1166,976,1421,464,828
# 873	1192,1426,1446,960,862,1092,1512,1164,1276,1042
# 878	1426,862,960,1120,958,1260,887,592,1153,1192
# 888	745,1463,1643,1142,1449,1154,1286,656,1192,865
# 889	1159,1643,1160,1449,745,1589,793,915,958,896
# 892	745,1463,1169,361,1142,1585,865,960,592,1298
# 893	745,836,1426,592,854,1142,733,605,1169,965
# 894	1449,1463,1643,1512,854,745,592,57,1169,1062
# 895	767,884,854,1160,950,1159,1313,601,1262,644
# 899	1167,793,6,1426,745,904,960,884,592,557
# 901	34,1192,1446,263,775,1426,1314,1278,27,634
# 902	998,960,791,1153,793,1113,1260,1052,811,1120
# 905	854,641,1463,969,791,1069,1512,1173,1116,432
# 909	1063,1185,1512,394,1451,337,593,842,1117,1041
# 910	960,1120,1172,1069,1126,848,592,947,1463,1204
# 911	1159,1252,958,1160,793,108,115,1426,221,798
# 913	1643,798,1252,793,1449,108,958,522,632,1160
# 915	1512,308,6,1434,791,903,1286,1166,1167,960
# 917	767,593,800,1053,842,1313,1174,1418,1286,836
# 921	634,916,351,1218,680,791,115,908,580,980
# 927	1159,634,115,1160,1245,986,1084,1019,1218,980
# 932	854,1463,1169,1512,1380,1126,1062,592,589,1176
# 933	1252,884,1449,1643,533,592,221,793,1368,543
# 934	1643,1512,1463,1449,318,1313,320,1623,1131,966
# 940	1426,1159,1063,1451,500,958,16,703,1163,862
# 941	1159,1163,767,1129,1184,1282,1615,16,565,107
# 942	1063,394,1185,966,1313,143,1643,1380,1218,1463
# 943	853,1163,1159,1615,962,817,16,774,583,741

# %%
## Writing output string to output.txt file

output_file = open("output.txt", "w")
output_file.write(final_str)
output_file.close()
